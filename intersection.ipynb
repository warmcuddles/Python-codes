# %%
# Defining Functions
f = lambda x: x**4 - 2*(x**3) - 19*(x**2) + 20*x
g = lambda x:  -(x**2) + 4*x + 12

x = np.arange(-50, 50, 1)  # setting the x axis range

# w/o using scipy
import matplotlib.pyplot as plt
import numpy as np
plt.figure()
plt.plot(x, f(x), 'r')
plt.plot(x, g(x))

idx = np.argwhere(np.diff(np.sign(f(x) - g(x)))).flatten()
plt.plot(x[idx], f(x)[idx], 'ro')

plt.ylim(-1000, 1000)

print(list(zip(x[idx], g(x)[idx]))) # Not that accurate
# Out:
# [(-4, -20), (5, 7)]
